# %% [markdown]
# ## importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## importing dataset

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## 1. males and females participated in the test

# %%
df["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# ## 2. Students parental level of education

# %%
sns.set(font_scale=2)
df['parental level of education'].value_counts().plot(kind='bar', figsize=(7,7))
plt.xlabel("parental education")
plt.ylabel("Count of parents")
plt.title("Student's Parental level of Education")
# Out:
# Text(0.5, 1.0, "Student's Parental level of Education")

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 3. scores most on average for math, reading and writing based on

# %% [markdown]
# ## . Gender

# %%
df.groupby('gender')['math score','writing score','reading score'].mean()
# Out:
#         math score  writing score  reading score
# gender
# female   63.376448      72.467181      72.590734
# male     68.821577      63.446058      65.545643

# %% [markdown]
# ## .Test preparation course

# %%
df.groupby(['test preparation course']).mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# # 4.scoring variation for math, reading and writing based on

# %% [markdown]
# ## . Gender

# %%
df[['gender', 'math score', 'reading score', 'writing score']].groupby('gender').std()
# Out:
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %% [raw]
#  comparatively females have more variation in their math score.
#  For writing and reading scores there is no considerable variation for both.

# %%
sns.boxplot(x="gender", y="math score", data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %% [markdown]
# Males have comparatively high marks for maths.

# %%
sns.boxplot(x="gender", y="writing score", data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='writing score'>

# %% [markdown]
# There is slight difference between the scores of both gender in writing.

# %%
sns.boxplot(x="gender", y="reading score", data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='reading score'>

# %% [markdown]
# ## . Test preperation course

# %%
df[['test preparation course', 'math score', 'reading score', 'writing score']].groupby('test preparation course').std()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %%
sns.boxplot(x="test preparation course", y="math score", data=df)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='math score'>

# %%
sns.boxplot(x="test preparation course", y="reading score", data=df)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='reading score'>

# %%
sns.boxplot(x="test preparation course", y="writing score", data=df)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='writing score'>

# %% [markdown]
# # 5. Top 25% of students based on their maths score

# %%
a=df.sort_values(by=['math score'],ascending=False).head(255)
a
a.loc[: ,['gender','math score']]
# Out:
#      gender  math score
# 999    male         100
# 996    male         100
# 515  female         100
# 517  female         100
# 516  female         100
# ..      ...         ...
# 851    male          77
# 849    male          77
# 850    male          77
# 421  female          77
# 414  female          77
#
# [255 rows x 2 columns]
